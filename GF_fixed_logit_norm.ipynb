# %% [markdown]
# # Libraries

# %%
import mechanism.annealed_logit_flow as alf

# %% [markdown]
# # L=3

# %%
system = alf.build_annealed_classes(
    L=3, a=-1, v=32, m=8, s=2, R=32, seed=1
)

results = alf.simulate_penalized_gradient_flow(
    system,
    lambda_reg=0.0000000000001,
    lr=0.1,
    steps=10000,
    record_every=5,
    tol=None,
    verbose=True,
)

fig, axs = alf.plot_three_requested(results, tau=0.50)
# Out:
# step=  1000  norm=39.261306  loss=1.292101  err_soft=0.615822
# step=  2000  norm=52.687239  loss=1.269549  err_soft=0.610809
# step=  3000  norm=61.238125  loss=1.262539  err_soft=0.609227
# step=  4000  norm=67.618797  loss=1.259147  err_soft=0.608457
# step=  5000  norm=72.749596  loss=1.257152  err_soft=0.608001
# step=  6000  norm=77.060841  loss=1.255840  err_soft=0.607700
# step=  7000  norm=80.790286  loss=1.254912  err_soft=0.607487
# step=  8000  norm=84.083839  loss=1.254220  err_soft=0.607328
# step=  9000  norm=87.037800  loss=1.253686  err_soft=0.607205
# step= 10000  norm=89.719225  loss=1.253261  err_soft=0.607107

# %%
fig, axs = alf.plot_three_requested(results, tau=0.50)
