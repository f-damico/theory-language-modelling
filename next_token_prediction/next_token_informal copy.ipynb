# %% [markdown]
# # Libraries and functions

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
from tqdm import tqdm
import sys
from pathlib import Path


project_root = Path("./")   # adjust to your real path

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from torch.utils.data import DataLoader

from rhm_barriers_rhos import compute_rhm_observables, plot_predicted_test_curves_from_rhm_observables, plot_margin_learning_order

# %% [markdown]
# # Test

# %%
res = compute_rhm_observables(
    num_features=64,
    num_classes=64,
    num_synonyms=4,
    tuple_size=2,
    num_layers=4,
    seed_rules=1,
    seed_sample=1,
    train_size=65536,
    test_size=4096,
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## L=3

# %%
curves = plot_predicted_test_curves_from_rhm_observables(res, norm_grid=np.logspace(0,8,100))
# Out:
# /mnt/beegfs/2a/mb12724/franc/theory-language-modelling/next_token_prediction/./rhm_barriers_rhos.py:627: RuntimeWarning: invalid value encountered in logaddexp
#   return np.logaddexp(0.0, -x)

# %%
order = plot_margin_learning_order(res, split="test")

# %% [markdown]
# ## L=4

# %%
curves = plot_predicted_test_curves_from_rhm_observables(res, norm_grid=np.logspace(0,10,100))

# %%
order = plot_margin_learning_order(res, split="test")
