# %% [markdown]
# # Libraries and functions

# %%
import numpy as np

import sys
from pathlib import Path

# path to the directory that CONTAINS the package folder
project_root = Path("/mnt/beegfs/2a/mb12724/theory-language-modeling/")   # adjust to your real path

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from BP.run_global_budget import simulate_bp_lambda_sweep

from BP.run import plot_both, plot_hierarchy_observables

# %% [markdown]
# # Flat rules

# %%
name_save = "global_test_1"

# %%
res = simulate_bp_lambda_sweep(
    num_features=32,
    num_classes=32,
    num_synonyms=8,
    tuple_size=2,
    num_layers=3,
    train_size=32768,
    test_size=2048,
    lambda_values=np.logspace(-0.5,1.,20),
    seed_rules=0,
    seed_sample=0,
)

np.save("./data/BP/"+name_save, res, allow_pickle=True)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 res = simulate_bp_lambda_sweep(
#       2     num_features=32,
#       3     num_classes=32,
#       4     num_synonyms=8,
#       5     tuple_size=2,
#       6     num_layers=3,
#       7     train_size=32768,
#       8     test_size=2048,
#       9     lambda_values=np.logspace(-0.5,1.,20),
#      10     seed_rules=0,
#      11     seed_sample=0,
#      12 )
#      14 np.save("./data/BP/"+name_save, res, allow_pickle=True)
#
# File /mnt/beegfs/2a/mb12724/theory-language-modelling/BP/run_global_budget.py:399, in simulate_bp_lambda_sweep(num_features, num_classes, num_synonyms, tuple_size, num_layers, train_size, test_size, lambda_values, seed_rules, seed_sample, max_test_samples, root_prior)
#     396 sweep: List[Dict[str, Any]] = []
# ...

# %%
res = np.load("./data/BP/"+name_save+".npy", allow_pickle=True).item()

# %%
fig, axs = plot_both(res)

# %%
fig2, axs2 = plot_hierarchy_observables(res)
